# %%
import pandas as pd
from pathlib import Path

data_path = Path(r"C:\Users\Мартинсон Диана\metric tree\data\raw\ml-25m")

print(" ПРОВЕРКА ДАННЫХ \n")

# Проверяем ratings.csv
print("1. Ratings.csv:")
ratings = pd.read_csv(data_path / "ratings.csv", nrows=5)
print(f"   Колонки: {list(ratings.columns)}")
print(f"   Пример данных:\n{ratings.head(3)}\n")

# Проверяем movies.csv
print("2. Movies.csv:")
movies = pd.read_csv(data_path / "movies.csv", nrows=5)
print(f"   Колонки: {list(movies.columns)}")
print(f"   Пример данных:\n{movies.head(3)}\n")

# Считаем количество строк (быстро)
import subprocess
result = subprocess.run(['powershell', '-Command', f'Get-Content "data/raw/ml-25m/ratings.csv" | Measure-Object -Line'], 
                       capture_output=True, text=True)
# Out:
#  ПРОВЕРКА ДАННЫХ
#
# 1. Ratings.csv:
#    Колонки: ['userId', 'movieId', 'rating', 'timestamp']
#    Пример данных:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
#
# 2. Movies.csv:
#    Колонки: ['movieId', 'title', 'genres']
#    Пример данных:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
